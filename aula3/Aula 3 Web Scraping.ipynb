# %%
#selenium automacao web
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys

navegador = webdriver.Chrome()


#1 Pegar a cotacao do dolar
navegador.get("https://www.google.com.br/")
#xpath #identifica elementos no site

navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação dólar")
navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_dolar = navegador.find_element('xpath', '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')
print (cotacao_dolar)


#2 Pegar a cotacao do euro
navegador.get("https://www.google.com.br/")
navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação euro")
navegador.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
cotacao_euro = navegador.find_element('xpath', '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')
print (cotacao_euro)

#3 Pegar a cotacao do ouro
navegador.get("https://www.melhorcambio.com/ouro-hoje")
cotacao_ouro = navegador.find_element('xpath', '//*[@id="comercial"]').get_attribute('value')
cotacao_ouro = cotacao_ouro.replace(",", ".")
print (cotacao_ouro)

navegador.quit()
# Out:
# 5.096
# 5.5273764000000005
# 315.12

# %% [markdown]
# - Importando a base de dados

# %%
#4 Atualizar a base

import pandas as pd

tabela = pd.read_excel ("Produtos.xlsx")
display (tabela)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %% [markdown]
# - Atualizando os preços e o cálculo do Preço Final

# %%
#5 Atualizar a cotacao

tabela.loc[tabela ["Moeda"] == "Dólar","Cotação"] = float(cotacao_dolar)
tabela.loc[tabela ["Moeda"] == "Euro","Cotação"] = float(cotacao_euro)
tabela.loc[tabela ["Moeda"] == "Ouro","Cotação"] = float(cotacao_ouro)


#Recalcular os precos

#Preco de compra = cotacao*preco origina

tabela["Preço de Compra"] = tabela ["Cotação"] * tabela ["Preço Original"]
tabela["Preço de Venda"] = tabela ["Preço de Compra"] * tabela ["Margem"]
display (tabela)

#Preco de venda = preco de compra * margem
# Out:
#          Produtos  Preço Original  Moeda     Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.096000       5095.94904    1.40
# 1   Carro Renault         4500.00   Euro    5.527376      24873.19380    2.00
# 2   Notebook Dell          899.99  Dólar    5.096000       4586.34904    1.70
# 3          IPhone          799.00  Dólar    5.096000       4071.70400    1.70
# 4      Carro Fiat         3000.00   Euro    5.527376      16582.12920    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.096000       2448.52608    2.00
# 6        Joia 20g           20.00   Ouro  315.120000       6302.40000    1.15
#
#    Preço de Venda
# 0     7134.328656
# 1    49746.387600
# 2     7796.793368
# 3     6921.896800
# 4    31506.045480
# 5     4897.052160
# 6     7247.760000

# %%
#6 Exportar a base atualizada
tabela.to_excel ("Produtos_Novo.xlsx", index=False) #index=false para nao exportar o indice que o phyton gera na tabela

# %%
# !pip install selenium
